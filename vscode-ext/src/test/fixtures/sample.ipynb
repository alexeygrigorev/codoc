# %%
# @cell_id=hello
    def greet(name):
        print(f'Hello, {name}!')
        return name

    greet('World')
# Out:
# Hello, World!
# 'World'

# %%
# @cell_id=setup
# @language=python
import os
data = [1, 2, 3]

# %%
# No cell_id marker here
print('This cell has no ID')
# Out:
# This cell has no ID

# %% [markdown]
# # This is a markdown cell — should be skipped

# %%
# @cell_id=error-cell
1 / 0
# Out:
# Traceback (most recent call last):
#   File "<stdin>", line 1
# ZeroDivisionError: division by zero
