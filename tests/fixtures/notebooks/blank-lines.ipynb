# %%
# @cell_id=test-blank-linesimport requestsrepo_owner = 'evidentlyai'repo_name = 'docs'branch_name = 'main'url = f"https://github.com/{repo_owner}/{repo_name}/archive/refs/heads/{branch_name}.zip"
