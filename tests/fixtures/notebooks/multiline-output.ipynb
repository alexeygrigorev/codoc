# %%
# @cell_id=ten-lines
for i in range(1, 11):
    print(f"Line {i}")
# Out:
# Line 1
# Line 2
# Line 3
# Line 4
# Line 5
# Line 6
# Line 7
# Line 8
# Line 9
# Line 10

# %%
# @cell_id=three-lines
for letter in ['A', 'B', 'C']:
    print(letter)
# Out:
# A
# B
# C
